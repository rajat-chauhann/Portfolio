# %%
import json
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, LSTM, Dense
from tensorflow.keras.models import Model
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras import layers , activations , models , preprocessing , utils

# read in the contents of the file
with open('/kaggle/input/faq-datasets-for-chatbot-training/faq_results.txt') as f:
    data = f.read()

# parse the JSON data
data = json.loads(data)


# Extract questions and answers from the dataset
questions = [d['Question'] for d in data]
answers = [d['Answer'] for d in data]
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %%
len(questions)
# Out:
# 48

# %%
import pandas as pd
zippedList =  list(zip(questions, answers))
lines = pd.DataFrame(zippedList, columns = ['input' , 'output']) 
lines.head()
# Out:
#                                                input  \
# 0                           How do I book my flight?
# 1  What is the maximum number of seats that I can...
# 2               How can I book a seat for my infant?
# 3  My ticket was purchased from a travel agent. C...
# 4                How can I pay for my ticket online?
#
#                                               output
# 0  You can make a new booking by any of the follo...
# 1  You can book up to nine passengers in a single...
# 2  Booking an infant seat can be done through our...
# 3  Yes, You can modify your booking under Manage ...
# 4  You can use a credit card, debit card or Net B...

# %%
input_lines = list()
for line in lines.input:
    input_lines.append( line ) 

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( input_lines ) 
tokenized_input_lines = tokenizer.texts_to_sequences( input_lines ) 

length_list = list()
for token_seq in tokenized_input_lines:
    length_list.append( len( token_seq ))
max_input_length = np.array( length_list ).max()
print( 'Input max length is {}'.format( max_input_length ))

padded_input_lines = preprocessing.sequence.pad_sequences( tokenized_input_lines , maxlen=max_input_length , padding='post' )
encoder_input_data = np.array( padded_input_lines )
print( 'Encoder input data shape -> {}'.format( encoder_input_data.shape ))

input_word_dict = tokenizer.word_index
num_input_tokens = len( input_word_dict )+1
print( 'Number of Input tokens = {}'.format( num_input_tokens))
# Out:
# Input max length is 33
# Encoder input data shape -> (48, 33)
# Number of Input tokens = 196

# %%
output_lines = list()
for line in lines.output:
    output_lines.append( '<START> ' + line + ' <END>' )  

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts( output_lines ) 
tokenized_output_lines = tokenizer.texts_to_sequences( output_lines ) 

length_list = list()
for token_seq in tokenized_output_lines:
    length_list.append( len( token_seq ))
max_output_length = np.array( length_list ).max()
print( 'Output max length is {}'.format( max_output_length ))

padded_output_lines = preprocessing.sequence.pad_sequences( tokenized_output_lines , maxlen=max_output_length, padding='post' )
decoder_input_data = np.array( padded_output_lines )
print( 'Decoder input data shape -> {}'.format( decoder_input_data.shape ))

output_word_dict = tokenizer.word_index
num_output_tokens = len( output_word_dict )+1
print( 'Number of Output tokens = {}'.format( num_output_tokens))
# Out:
# Output max length is 227
# Decoder input data shape -> (48, 227)
# Number of Output tokens = 886

# %%
encoder_inputs = tf.keras.layers.Input(shape=( None , ))
encoder_embedding = tf.keras.layers.Embedding( num_input_tokens, 256 , mask_zero=True ) (encoder_inputs)
encoder_outputs , state_h , state_c = tf.keras.layers.LSTM( 256 , return_state=True , recurrent_dropout=0.2 , dropout=0.2 )( encoder_embedding )
encoder_states = [ state_h , state_c ]

decoder_inputs = tf.keras.layers.Input(shape=( None ,  ))
decoder_embedding = tf.keras.layers.Embedding( num_output_tokens, 256 , mask_zero=True) (decoder_inputs)
decoder_lstm = tf.keras.layers.LSTM( 256 , return_state=True , return_sequences=True , recurrent_dropout=0.2 , dropout=0.2)
decoder_outputs , _ , _ = decoder_lstm ( decoder_embedding , initial_state=encoder_states )
decoder_dense = tf.keras.layers.Dense( num_output_tokens , activation=tf.keras.activations.softmax ) 
output = decoder_dense ( decoder_outputs )

model = tf.keras.models.Model([encoder_inputs, decoder_inputs], output )
model.compile(optimizer=tf.keras.optimizers.Adam(), loss='categorical_crossentropy')

model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, None)]       0           []
#
#  input_2 (InputLayer)           [(None, None)]       0           []
#
#  embedding (Embedding)          (None, None, 256)    50176       ['input_1[0][0]']
#
#  embedding_1 (Embedding)        (None, None, 256)    226816      ['input_2[0][0]']
#
#  lstm (LSTM)                    [(None, 256),        525312      ['embedding[0][0]']
#                                  (None, 256),
#                                  (None, 256)]
#
#  lstm_1 (LSTM)                  [(None, None, 256),  525312      ['embedding_1[0][0]',
#                                  (None, 256),                     'lstm[0][1]',
#                                  (None, 256)]                     'lstm[0][2]']
#
#  dense (Dense)                  (None, None, 886)    227702      ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 1,555,318
# Trainable params: 1,555,318
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
decoder_target_data = list()
for token_seq in tokenized_output_lines:
    decoder_target_data.append( token_seq[ 1 : ] ) 
    
padded_output_lines = preprocessing.sequence.pad_sequences( decoder_target_data , maxlen=max_output_length, padding='post' )
onehot_output_lines = utils.to_categorical( padded_output_lines , num_output_tokens )
decoder_target_data = np.array(onehot_output_lines )
print( 'Decoder target data shape -> {}'.format( decoder_target_data.shape ))
# Out:
# Decoder target data shape -> (48, 227, 886)

# %%
model.fit([encoder_input_data , decoder_input_data], decoder_target_data, batch_size=124, epochs=500) 
model.save( 'model.h5' )
# Out:
# Epoch 1/500
# 1/1 [==============================] - 13s 13s/step - loss: 6.7867
# Epoch 2/500
# 1/1 [==============================] - 2s 2s/step - loss: 6.7828
# Epoch 3/500
# 1/1 [==============================] - 1s 1s/step - loss: 6.7783
# Epoch 4/500
# 1/1 [==============================] - 2s 2s/step - loss: 6.7726
# Epoch 5/500
# 1/1 [==============================] - 1s 1s/step - loss: 6.7640
# Epoch 6/500
# 1/1 [==============================] - 1s 1s/step - loss: 6.7476
# Epoch 7/500
# 1/1 [==============================] - 1s 1s/step - loss: 6.7021
# Epoch 8/500
# 1/1 [==============================] - 1s 1s/step - loss: 6.5841
# Epoch 9/500
# 1/1 [==============================] - 2s 2s/step - loss: 6.4310
# Epoch 10/500
# 1/1 [==============================] - 2s 2s/step - loss: 6.2817
# Epoch 11/500
# 1/1 [==============================] - 2s 2s/step - loss: 6.1536
# Epoch 12/500
# 1/1 [==============================] - 1s 1s/step - loss: 6.0554
# Epoch 13/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.9903
# Epoch 14/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.9544
# Epoch 15/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.9325
# Epoch 16/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.9161
# Epoch 17/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.9006
# Epoch 18/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8895
# Epoch 19/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8814
# Epoch 20/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.8745
# Epoch 21/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8704
# Epoch 22/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.8679
# Epoch 23/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.8654
# Epoch 24/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8604
# Epoch 25/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8553
# Epoch 26/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8482
# Epoch 27/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8393
# Epoch 28/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8301
# Epoch 29/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8212
# Epoch 30/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.8139
# Epoch 31/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.8064
# Epoch 32/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.8001
# Epoch 33/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.7935
# Epoch 34/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.7882
# Epoch 35/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.7812
# Epoch 36/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.7727
# Epoch 37/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.7643
# Epoch 38/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.7556
# Epoch 39/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.7485
# Epoch 40/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.7405
# Epoch 41/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.7321
# Epoch 42/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.7245
# Epoch 43/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.7160
# Epoch 44/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.7068
# Epoch 45/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.6976
# Epoch 46/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.6899
# Epoch 47/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.6811
# Epoch 48/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.6726
# Epoch 49/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.6645
# Epoch 50/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.6548
# Epoch 51/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.6454
# Epoch 52/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.6364
# Epoch 53/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.6262
# Epoch 54/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.6165
# Epoch 55/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.6064
# Epoch 56/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.5962
# Epoch 57/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.5861
# Epoch 58/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.5757
# Epoch 59/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.5650
# Epoch 60/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.5533
# Epoch 61/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.5413
# Epoch 62/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.5289
# Epoch 63/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.5176
# Epoch 64/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.5045
# Epoch 65/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.4919
# Epoch 66/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.4781
# Epoch 67/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.4648
# Epoch 68/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.4509
# Epoch 69/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.4354
# Epoch 70/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.4209
# Epoch 71/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.4067
# Epoch 72/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.3911
# Epoch 73/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.3731
# Epoch 74/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.3571
# Epoch 75/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.3412
# Epoch 76/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.3255
# Epoch 77/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.3064
# Epoch 78/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.2888
# Epoch 79/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.2680
# Epoch 80/500
# 1/1 [==============================] - 2s 2s/step - loss: 5.2484
# Epoch 81/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.2298
# Epoch 82/500
# 1/1 [==============================] - 1s 1s/step - loss: 5.2073
# Epoch 83/500
# 1/1 [==============================] - 1s 1s/step - loss: 5
500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1801
# Epoch 438/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1815
# Epoch 439/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1820
# Epoch 440/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1761
# Epoch 441/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1755
# Epoch 442/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1713
# Epoch 443/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1735
# Epoch 444/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1721
# Epoch 445/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1719
# Epoch 446/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1715
# Epoch 447/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1673
# Epoch 448/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1691
# Epoch 449/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1665
# Epoch 450/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1638
# Epoch 451/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1639
# Epoch 452/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1614
# Epoch 453/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1606
# Epoch 454/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1625
# Epoch 455/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1585
# Epoch 456/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1587
# Epoch 457/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1585
# Epoch 458/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1572
# Epoch 459/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1544
# Epoch 460/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1562
# Epoch 461/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1518
# Epoch 462/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1539
# Epoch 463/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1514
# Epoch 464/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1505
# Epoch 465/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1505
# Epoch 466/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1523
# Epoch 467/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1463
# Epoch 468/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1467
# Epoch 469/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1467
# Epoch 470/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1467
# Epoch 471/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1429
# Epoch 472/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1437
# Epoch 473/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1401
# Epoch 474/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1399
# Epoch 475/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1405
# Epoch 476/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1379
# Epoch 477/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1392
# Epoch 478/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1379
# Epoch 479/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1363
# Epoch 480/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1332
# Epoch 481/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1384
# Epoch 482/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1327
# Epoch 483/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1340
# Epoch 484/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1331
# Epoch 485/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1333
# Epoch 486/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1312
# Epoch 487/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1319
# Epoch 488/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1302
# Epoch 489/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1302
# Epoch 490/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1269
# Epoch 491/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1248
# Epoch 492/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1275
# Epoch 493/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1246
# Epoch 494/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1271
# Epoch 495/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1254
# Epoch 496/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1235
# Epoch 497/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1232
# Epoch 498/500
# 1/1 [==============================] - 2s 2s/step - loss: 0.1210
# Epoch 499/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1236
# Epoch 500/500
# 1/1 [==============================] - 1s 1s/step - loss: 0.1193

# %%
def make_inference_models():
    
    encoder_model = tf.keras.models.Model(encoder_inputs, encoder_states)
    
    decoder_state_input_h = tf.keras.layers.Input(shape=(256,))
    decoder_state_input_c = tf.keras.layers.Input(shape=(256,))
    
    decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
    
    decoder_outputs, state_h, state_c = decoder_lstm(
        decoder_embedding , initial_state=decoder_states_inputs)
    decoder_states = [state_h, state_c]
    decoder_outputs = decoder_dense(decoder_outputs)
    decoder_model = tf.keras.models.Model(
        [decoder_inputs] + decoder_states_inputs,
        [decoder_outputs] + decoder_states)
    
    return encoder_model , decoder_model

# %%
import tensorflow as tf
def str_to_tokens( sentence : str ):
    words = sentence.lower().split()
    tokens_list = list()
    for word in words:
        tokens_list.append( input_word_dict[ word ] ) 
    return preprocessing.sequence.pad_sequences( [tokens_list] , maxlen=max_input_length , padding='post')

# %%
enc_model , dec_model = make_inference_models()
for epoch in range( encoder_input_data.shape[0] ):
    states_values = enc_model.predict( str_to_tokens( input( 'User: ' ).replace("?","") ) )
    empty_target_seq = np.zeros( ( 1 , 1 ) )
    empty_target_seq[0, 0] = output_word_dict['start']
    stop_condition = False
    decoded_translation = ''
    while not stop_condition :
        dec_outputs , h , c = dec_model.predict([ empty_target_seq ] + states_values )
        sampled_word_index = np.argmax( dec_outputs[0, -1, :] )
        sampled_word = None
        for word , index in output_word_dict.items() :
            if sampled_word_index == index :
                decoded_translation += ' {}'.format( word )
                sampled_word = word
        
        if sampled_word == 'end' or len(decoded_translation.split()) > max_output_length:
            stop_condition = True
            
        empty_target_seq = np.zeros( ( 1 , 1 ) )  
        empty_target_seq[ 0 , 0 ] = sampled_word_index
        states_values = [ h , c ] 

    print( "Bot:" +decoded_translation.replace(' end', '') )
    print()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 enc_model , dec_model = make_inference_models()
#       2 for epoch in range( encoder_input_data.shape[0] ):
# ----> 3     states_values = enc_model.predict( str_to_tokens( input( 'User: ' ).replace("?","") ) )
#       4     empty_target_seq = np.zeros( ( 1 , 1 ) )
#       5     empty_target_seq[0, 0] = output_word_dict['start']
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1191, in Kernel.raw_input(self, prompt)
#    1189     msg = "raw_input was called, but this frontend does not support input requests."
#    1190     raise StdinNotImplementedError(msg)
# -> 1191 return self._input_request(
#    1192     str(prompt),
#    1193     self._parent_ident["shell"],
#    1194     self.get_parent("shell"),
#    1195     password=False,
#    1196 )
#
# File /opt/conda/lib/python3.10/site-packages/ipykernel/kernelbase.py:1234, in Kernel._input_request(self, prompt, ident, parent, password)
#    1231 except KeyboardInterrupt:
#    1232     # re-raise KeyboardInterrupt, to truncate traceback
#    1233     msg = "Interrupted by user"
# -> 1234     raise KeyboardInterrupt(msg) from None
#    1235 except Exception:
#    1236     self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
